# %% [markdown]
# # Exploring Trending App Categories on Google Play Store

# %% [markdown]
# #### Discovering the various app categories on Google Play Store, analyzing trends to assist in finding the most suitable options for development

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
android_df = pd.read_csv('googleplaystore.csv')

# %%
android_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
android_df.shape
# Out:
# (10841, 13)

# %%
android_df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# 1.9                       1
# Name: Category, dtype: int64

# %%
android_df[android_df["Category"] == "1.9"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
android_df[android_df["Category"] == "1.9"].values
# Out:
# array([['Life Made WI-Fi Touchscreen Photo Frame', '1.9', 19.0, '3.0M',
#         '1,000+', 'Free', '0', 'Everyone', nan, 'February 11, 2018',
#         '1.0.19', '4.0 and up', nan]], dtype=object)

# %%
clean_lst = ['Life Made WI-Fi Touchscreen Photo Frame', 'LIFESTYLE', '1.9', 19.0, '3.0M',
        '1,000+', 'Free', '0', 'Everyone', 'LifeStyle', 'February 11, 2018',
        '1.0.19', '4.0 and up']

clean_lst
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame',
#  'LIFESTYLE',
#  '1.9',
#  19.0,
#  '3.0M',
#  '1,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'LifeStyle',
#  'February 11, 2018',
#  '1.0.19',
#  '4.0 and up']

# %%
android_df[android_df["Category"] == "1.9"] = clean_lst

# %%
android_df[android_df["Category"] == "1.9"]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
android_df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               383
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# Name: Category, dtype: int64

# %%
app_count = android_df["App"].value_counts()
app_count
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9660, dtype: int64

# %%
app_count[app_count > 1]
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# ESPN                                                 7
# Duolingo: Learn Languages Free                       7
# Candy Crush Saga                                     7
#                                                     ..
# Transenger – Ts Dating and Chat for Free             2
# Random Video Chat                                    2
# Clover Dating App                                    2
# Docs To Go™ Free Office Suite                        2
# English Dictionary - Offline                         2
# Name: App, Length: 798, dtype: int64

# %%
"Instagram" in app_count[app_count > 1].index
# Out:
# True

# %%
android_df[android_df["App"]== "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %%
android_df.duplicated(subset=['App'], keep="first").sum()
# Out:
# 1181

# %%
duplicate_apps_df = android_df[android_df.duplicated(subset=['App'], keep="last")]

duplicate_apps_df[duplicate_apps_df['App'] == "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device

# %%
duplicate_apps_df = android_df[android_df.duplicated(subset=['App'], keep="first")]

duplicate_apps_df[duplicate_apps_df['App'] == "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %%
# Check for duplicate rows based on the 'App' column, marking all duplicates as True
duplicate_apps_df = android_df[android_df.duplicated(subset=['App'], keep=False)]

duplicate_apps_df[duplicate_apps_df['App'] == "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %%
num_duplicate_apps = duplicate_apps_df['App'].nunique()
num_duplicate_apps
# Out:
# 798

# %%
duplicate_apps_df.shape
# Out:
# (1979, 13)

# %%
android_df.shape[0]
# Out:
# 10841

# %%
10841-1979
# Out:
# 8862

# %%
#PART TWO

# %%
# Make a dictionary

# %%
reviews_max = android_df.groupby('App')['Reviews'].max()

# %%
reviews_max["Instagram"]
# Out:
# '66577446'

# %%
duplicate_apps_df[duplicate_apps_df['App'] == "Instagram"]
# Out:
#             App Category Rating   Reviews                Size        Installs  \
# 2545  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 2604  Instagram   SOCIAL    4.5  66577446  Varies with device  1,000,000,000+
# 2611  Instagram   SOCIAL    4.5  66577313  Varies with device  1,000,000,000+
# 3909  Instagram   SOCIAL    4.5  66509917  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres   Last Updated         Current Ver  \
# 2545  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2604  Free     0           Teen  Social  July 31, 2018  Varies with device
# 2611  Free     0           Teen  Social  July 31, 2018  Varies with device
# 3909  Free     0           Teen  Social  July 31, 2018  Varies with device
#
#              Android Ver
# 2545  Varies with device
# 2604  Varies with device
# 2611  Varies with device
# 3909  Varies with device

# %%
reviews_max
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                   27
# +Download 4 Instagram Twitter                       40467
# - Free Comics - Comic Apps                            115
# .R                                                    259
# /u/app                                                573
#                                                     ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                               414
# 💎 I'm rich                                            718
# 💘 WhatsLov: Smileys of love, stickers and GIF       22098
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!       19
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    11661
# Name: Reviews, Length: 9660, dtype: object

# %%
# Create an empty list to store cleaned data

android_clean = []

# Create ann empty list to keep track of already added apps
already_added = []

# Check each row in dataFrame
for index, row in android_df.iterrows():
    name = row['App']
    n_reviews = row['Reviews']
    
    # check if the current app has the max number of reviews and has not been added before
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        android_clean.append(row) # Add whole record 
        already_added.append(name) # Add app name

# %%
len(android_clean)
# Out:
# 9660

# %%
android_clean
# Out:
# [App               Photo Editor & Candy Camera & Grid & ScrapBook
#  Category                                          ART_AND_DESIGN
#  Rating                                                       4.1
#  Reviews                                                      159
#  Size                                                         19M
#  Installs                                                 10,000+
#  Type                                                        Free
#  Price                                                          0
#  Content Rating                                          Everyone
#  Genres                                              Art & Design
#  Last Updated                                     January 7, 2018
#  Current Ver                                                1.0.0
#  Android Ver                                         4.0.3 and up
#  Name: 0, dtype: object,
#  App               U Launcher Lite – FREE Live Cool Themes, Hide ...
#  Category                                             ART_AND_DESIGN
#  Rating                                                          4.7
#  Reviews                                                       87510
#  Size                                                           8.7M
#  Installs                                                 5,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                                 Art & Design
#  Last Updated                                         August 1, 2018
#  Current Ver                                                   1.2.4
#  Android Ver                                            4.0.3 and up
#  Name: 2, dtype: object,
#  App               Sketch - Draw & Paint
#  Category                 ART_AND_DESIGN
#  Rating                              4.5
#  Reviews                          215644
#  Size                                25M
#  Installs                    50,000,000+
#  Type                               Free
#  Price                                 0
#  Content Rating                     Teen
#  Genres                     Art & Design
#  Last Updated               June 8, 2018
#  Current Ver          Varies with device
#  Android Ver                  4.2 and up
#  Name: 3, dtype: object,
#  App               Pixel Draw - Number Art Coloring Book
#  Category                                 ART_AND_DESIGN
#  Rating                                              4.3
#  Reviews                                             967
#  Size                                               2.8M
#  Installs                                       100,000+
#  Type                                               Free
#  Price                                                 0
#  Content Rating                                 Everyone
#  Genres                          Art & Design;Creativity
#  Last Updated                              June 20, 2018
#  Current Ver                                         1.1
#  Android Ver                                  4.4 and up
#  Name: 4, dtype: object,
#  App               Paper flowers instructions
#  Category                      ART_AND_DESIGN
#  Rating                                   4.4
#  Reviews                                  167
#  Size                                    5.6M
#  Installs                             50,000+
#  Type                                    Free
#  Price                                      0
#  Content Rating                      Everyone
#  Genres                          Art & Design
#  Last Updated                  March 26, 2017
#  Current Ver                              1.0
#  Android Ver                       2.3 and up
#  Name: 5, dtype: object,
#  App               Smoke Effect Photo Maker - Smoke Editor
#  Category                                   ART_AND_DESIGN
#  Rating                                                3.8
#  Reviews                                               178
#  Size                                                  19M
#  Installs                                          50,000+
#  Type                                                 Free
#  Price                                                   0
#  Content Rating                                   Everyone
#  Genres                                       Art & Design
#  Last Updated                               April 26, 2018
#  Current Ver                                           1.1
#  Android Ver                                  4.0.3 and up
#  Name: 6, dtype: object,
#  App               Infinite Painter
#  Category            ART_AND_DESIGN
#  Rating                         4.1
#  Reviews                      36815
#  Size                           29M
#  Installs                1,000,000+
#  Type                          Free
#  Price                            0
#  Content Rating            Everyone
#  Genres                Art & Design
#  Last Updated         June 14, 2018
#  Current Ver               6.1.61.1
#  Android Ver             4.2 and up
#  Name: 7, dtype: object,
#  App               Garden Coloring Book
#  Category                ART_AND_DESIGN
#  Rating                             4.4
#  Reviews                          13791
#  Size                               33M
#  Installs                    1,000,000+
#  Type                              Free
#  Price                                0
#  Content Rating                Everyone
#  Genres                    Art & Design
#  Last Updated        September 20, 2017
#  Current Ver                      2.9.2
#  Android Ver                 3.0 and up
#  Name: 8, dtype: object,
#  App               Kids Paint Free - Drawing Fun
#  Category                         ART_AND_DESIGN
#  Rating                                      4.7
#  Reviews                                     121
#  Size                                       3.1M
#  Installs                                10,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                  Art & Design;Creativity
#  Last Updated                       July 3, 2018
#  Current Ver                                 2.8
#  Android Ver                        4.0.3 and up
#  Name: 9, dtype: object,
#  App               Text on Photo - Fonteee
#  Category                   ART_AND_DESIGN
#  Rating                                4.4
#  Reviews                             13880
#  Size                                  28M
#  Installs                       1,000,000+
#  Type                                 Free
#  Price                                   0
#  Content Rating                   Everyone
#  Genres                       Art & Design
#  Last Updated             October 27, 2017
#  Current Ver                         1.0.4
#  Android Ver                    4.1 and up
#  Name: 10, dtype: object,
#  App               Name Art Photo Editor - Focus n Filters
#  Category                                   ART_AND_DESIGN
#  Rating                                                4.4
#  Reviews                                              8788
#  Size                                                  12M
#  Installs                                       1,000,000+
#  Type                                                 Free
#  Price                                                   0
#  Content Rating                                   Everyone
#  Genres                                       Art & Design
#  Last Updated                                July 31, 2018
#  Current Ver                                        1.0.15
#  Android Ver                                    4.0 and up
#  Name: 11, dtype: object,
#  App               Tattoo Name On My Photo Editor
#  Category                          ART_AND_DESIGN
#  Rating                                       4.2
#  Reviews                                    44829
#  Size                                         20M
#  Installs                             10,000,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                              Teen
#  Genres                              Art & Design
#  Last Updated                       April 2, 2018
#  Current Ver                                  3.8
#  Android Ver                           4.1 and up
#  Name: 12, dtype: object,
#  App               Mandala Coloring Book
#  Category                 ART_AND_DESIGN
#  Rating                              4.6
#  Reviews                            4326
#  Size                                21M
#  Installs                       100,000+
#  Type                               Free
#  Price                                 0
#  Content Rating                 Everyone
#  Genres                     Art & Design
#  Last Updated              June 26, 2018
#  Current Ver                       1.0.4
#  Android Ver                  4.4 and up
#  Name: 13, dtype: object,
#  App               3D Color Pixel by Number - Sandbox Art Coloring
#  Category                                           ART_AND_DESIGN
#  Rating                                                        4.4
#  Reviews                                                      1518
#  Size                                                          37M
#  Installs                                                 100,000+
#  Type                                                         Free
#  Price                                                           0
#  Content Rating                                           Everyone
#  Genres                                               Art & Design
#  Last Updated                                       August 3, 2018
#  Current Ver                                                 1.2.3
#  Android Ver                                            2.3 and up
#  Name: 14, dtype: object,
#  App               Learn To Draw Kawaii Characters
#  Category                           ART_AND_DESIGN
#  Rating                                        3.2
#  Reviews                                        55
#  Size                                         2.7M
#  Installs                                   5,000+
#  Type                                         Free
#  Price                                           0
#  Content Rating                           Everyone
#  Genres                               Art & Design
#  Last Updated                         June 6, 2018
#  Current Ver                                   NaN
#  Android Ver                            4.2 and up
#  Name: 15, dtype: object,
#  App               Photo Designer - Write your name with shapes
#  Category                                        ART_AND_DESIGN
#  Rating                                                     4.7
#  Reviews                                                   3632
#  Size                                                      5.5M
#  Installs                                              500,000+
#  Type                                                      Free
#  Price                                                        0
#  Content Rating                                        Everyone
#  Genres                                            Art & Design
#  Last Updated                                     July 31, 2018
#  Current Ver                                                3.1
#  Android Ver                                         4.1 and up
#  Name: 16, dtype: object,
#  App               350 Diy Room Decor Ideas
#  Category                    ART_AND_DESIGN
#  Rating                                 4.5
#  Reviews                                 27
#  Size                                   17M
#  Installs                           10,000+
#  Type                                  Free
#  Price                                    0
#  Content Rating                    Everyone
#  Genres                        Art & Design
#  Last Updated              November 7, 2017
#  Current Ver                            1.0
#  Android Ver                     2.3 and up
#  Name: 17, dtype: object,
#  App               FlipaClip - Cartoon animation
#  Category                         ART_AND_DESIGN
#  Rating                                      4.3
#  Reviews                                  194216
#  Size                                        39M
#  Installs                             5,000,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                             Art & Design
#  Last Updated                     August 3, 2018
#  Current Ver                               2.2.5
#  Android Ver                        4.0.3 and up
#  Name: 18, dtype: object,
#  App                 ibis Paint X
#  Category          ART_AND_DESIGN
#  Rating                       4.6
#  Reviews                   224399
#  Size                         31M
#  Installs             10,000,000+
#  Type                        Free
#  Price                          0
#  Content Rating          Everyone
#  Genres              Art & Design
#  Last Updated       July 30, 2018
#  Current Ver                5.5.4
#  Android Ver           4.1 and up
#  Name: 19, dtype: object,
#  App               Logo Maker - Small Business
#  Category                       ART_AND_DESIGN
#  Rating                                    4.0
#  Reviews                                   450
#  Size                                      14M
#  Installs                             100,000+
#  Type                                     Free
#  Price                                       0
#  Content Rating                       Everyone
#  Genres                           Art & Design
#  Last Updated                   April 20, 2018
#  Current Ver                               4.0
#  Android Ver                        4.1 and up
#  Name: 20, dtype: object,
#  App               Boys Photo Editor - Six Pack & Men's Suit
#  Category                                     ART_AND_DESIGN
#  Rating                                                  4.1
#  Reviews                                                 654
#  Size                                                    12M
#  Installs                                           100,000+
#  Type                                                   Free
#  Price                                                     0
#  Content Rating                                     Everyone
#  Genres                                         Art & Design
#  Last Updated                                 March 20, 2018
#  Current Ver                                             1.1
#  Android Ver                                    4.0.3 and up
#  Name: 21, dtype: object,
#  App               Superheroes Wallpapers | 4K Backgrounds
#  Category                                   ART_AND_DESIGN
#  Rating                                                4.7
#  Reviews                                              7699
#  Size                                                 4.2M
#  Installs                                         500,000+
#  Type                                                 Free
#  Price                                                   0
#  Content Rating                               Everyone 10+
#  Genres                                       Art & Design
#  Last Updated                                July 12, 2018
#  Current Ver                                       2.2.6.2
#  Android Ver                                  4.0.3 and up
#  Name: 22, dtype: object,
#  App               HD Mickey Minnie Wallpapers
#  Category                       ART_AND_DESIGN
#  Rating                                    4.7
#  Reviews                                   118
#  Size                                      23M
#  Installs                              50,000+
#  Type                                     Free
#  Price                                       0
#  Content Rating                       Everyone
#  Genres                           Art & Design
#  Last Updated                     July 7, 2018
#  Current Ver                             1.1.3
#  Android Ver                        4.1 and up
#  Name: 24, dtype: object,
#  App               Harley Quinn wallpapers HD
#  Category                      ART_AND_DESIGN
#  Rating                                   4.8
#  Reviews                                  192
#  Size                                    6.0M
#  Installs                             10,000+
#  Type                                    Free
#  Price                                      0
#  Content Rating                      Everyone
#  Genres                          Art & Design
#  Last Updated                  April 25, 2018
#  Current Ver                              1.5
#  Android Ver                       3.0 and up
#  Name: 25, dtype: object,
#  App               Colorfit - Drawing & Coloring
#  Category                         ART_AND_DESIGN
#  Rating                                      4.7
#  Reviews                                   20260
#  Size                                        25M
#  Installs                               500,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                  Art & Design;Creativity
#  Last Updated                   October 11, 2017
#  Current Ver                               1.0.8
#  Android Ver                        4.0.3 and up
#  Name: 26, dtype: object,
#  App               Animated Photo Editor
#  Category                 ART_AND_DESIGN
#  Rating                              4.1
#  Reviews                             203
#  Size                               6.1M
#  Installs                       100,000+
#  Type                               Free
#  Price                                 0
#  Content Rating                 Everyone
#  Genres                     Art & Design
#  Last Updated             March 21, 2018
#  Current Ver                        1.03
#  Android Ver                4.0.3 and up
#  Name: 27, dtype: object,
#  App               Pencil Sketch Drawing
#  Category                 ART_AND_DESIGN
#  Rating                              3.9
#  Reviews                             136
#  Size                               4.6M
#  Installs                        10,000+
#  Type                               Free
#  Price                                 0
#  Content Rating                 Everyone
#  Genres                     Art & Design
#  Last Updated              July 12, 2018
#  Current Ver                         6.0
#  Android Ver                  2.3 and up
#  Name: 28, dtype: object,
#  App               Easy Realistic Drawing Tutorial
#  Category                           ART_AND_DESIGN
#  Rating                                        4.1
#  Reviews                                       223
#  Size                                         4.2M
#  Installs                                 100,000+
#  Type                                         Free
#  Price                                           0
#  Content Rating                           Everyone
#  Genres                               Art & Design
#  Last Updated                      August 22, 2017
#  Current Ver                                   1.0
#  Android Ver                            2.3 and up
#  Name: 29, dtype: object,
#  App               Pink Silver Bow Keyboard Theme
#  Category                          ART_AND_DESIGN
#  Rating                                       4.2
#  Reviews                                     1120
#  Size                                        9.2M
#  Installs                                100,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                              Art & Design
#  Last Updated                       July 12, 2018
#  Current Ver                          6.7.12.2018
#  Android Ver                         4.0.3 and up
#  Name: 30, dtype: object,
#  App               Art Drawing Ideas
#  Category             ART_AND_DESIGN
#  Rating                          4.1
#  Reviews                         227
#  Size                           5.2M
#  Installs                    50,000+
#  Type                           Free
#  Price                             0
#  Content Rating             Everyone
#  Genres                 Art & Design
#  Last Updated           May 31, 2018
#  Current Ver                     1.2
#  Android Ver              2.3 and up
#  Name: 31, dtype: object,
#  App               Anime Manga Coloring Book
#  Category                     ART_AND_DESIGN
#  Rating                                  4.5
#  Reviews                                5035
#  Size                                    11M
#  Installs                           100,000+
#  Type                                   Free
#  Price                                     0
#  Content Rating                     Everyone
#  Genres                         Art & Design
#  Last Updated                  July 19, 2018
#  Current Ver                            2.20
#  Android Ver                      4.0 and up
#  Name: 32, dtype: object,
#  App               Easy Origami Ideas
#  Category              ART_AND_DESIGN
#  Rating                           4.2
#  Reviews                         1015
#  Size                             11M
#  Installs                    100,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres                  Art & Design
#  Last Updated         January 6, 2018
#  Current Ver                    1.1.0
#  Android Ver               4.1 and up
#  Name: 33, dtype: object,
#  App               I Creative Idea
#  Category           ART_AND_DESIGN
#  Rating                        4.7
#  Reviews                       353
#  Size                         4.2M
#  Installs                  10,000+
#  Type                         Free
#  Price                           0
#  Content Rating               Teen
#  Genres               Art & Design
#  Last Updated       April 27, 2018
#  Current Ver                   1.6
#  Android Ver            4.1 and up
#  Name: 34, dtype: object,
#  App               How to draw Ladybug and Cat Noir
#  Category                            ART_AND_DESIGN
#  Rating                                         3.8
#  Reviews                                        564
#  Size                                          9.2M
#  Installs                                  100,000+
#  Type                                          Free
#  Price                                            0
#  Content Rating                            Everyone
#  Genres                                Art & Design
#  Last Updated                         July 11, 2018
#  Current Ver                                    2.1
#  Android Ver                             4.1 and up
#  Name: 35, dtype: object,
#  App               Floor Plan Creator
#  Category              ART_AND_DESIGN
#  Rating                           4.1
#  Reviews                        36639
#  Size              Varies with device
#  Installs                  5,000,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres                  Art & Design
#  Last Updated           July 14, 2018
#  Current Ver       Varies with device
#  Android Ver             2.3.3 and up
#  Name: 37, dtype: object,
#  App               PIP Camera - PIP Collage Maker
#  Category                          ART_AND_DESIGN
#  Rating                                       4.7
#  Reviews                                      158
#  Size                                         11M
#  Installs                                 10,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                              Art & Design
#  Last Updated                   November 29, 2017
#  Current Ver                                  1.3
#  Android Ver                         4.0.3 and up
#  Name: 38, dtype: object,
#  App               How To Color Disney Princess - Coloring Pages
#  Category                                         ART_AND_DESIGN
#  Rating                                                      4.0
#  Reviews                                                     591
#  Size                                                       9.4M
#  Installs                                               500,000+
#  Type                                                       Free
#  Price                                                         0
#  Content Rating                                         Everyone
#  Genres                                             Art & Design
#  Last Updated                                     March 31, 2018
#  Current Ver                                                   1
#  Android Ver                                          4.0 and up
#  Name: 39, dtype: object,
#  App               Drawing Clothes Fashion Ideas
#  Category                         ART_AND_DESIGN
#  Rating                                      4.2
#  Reviews                                     117
#  Size                                        15M
#  Installs                                10,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                             Art & Design
#  Last Updated                      July 20, 2018
#  Current Ver                               2.0.1
#  Android Ver                        4.0.3 and up
#  Name: 40, dtype: object,
#  App               Sad Poetry Photo Frames 2018
#  Category                        ART_AND_DESIGN
#  Rating                                     4.5
#  Reviews                                    176
#  Size                                       10M
#  Installs                              100,000+
#  Type                                      Free
#  Price                                        0
#  Content Rating                        Everyone
#  Genres                            Art & Design
#  Last Updated                     April 2, 2018
#  Current Ver                                1.0
#  Android Ver                       4.0.3 and up
#  Name: 41, dtype: object,
#  App                         Paint Splash!
#  Category                   ART_AND_DESIGN
#  Rating                                3.8
#  Reviews                              2206
#  Size                                 1.2M
#  Installs                         100,000+
#  Type                                 Free
#  Price                                   0
#  Content Rating                   Everyone
#  Genres            Art & Design;Creativity
#  Last Updated               April 15, 2018
#  Current Ver                          1.46
#  Android Ver                    4.1 and up
#  Name: 43, dtype: object,
#  App               Popsicle Sticks and Similar DIY Craft Ideas
#  Category                                       ART_AND_DESIGN
#  Rating                                                    4.2
#  Reviews                                                    26
#  Size                                                      12M
#  Installs                                              10,000+
#  Type                                                     Free
#  Price                                                       0
#  Content Rating                                       Everyone
#  Genres                                           Art & Design
#  Last Updated                                  January 3, 2018
#  Current Ver                                             1.0.0
#  Android Ver                                        4.1 and up
#  Name: 44, dtype: object,
#  App               Canva: Poster, banner, card maker & graphic de...
#  Category                                             ART_AND_DESIGN
#  Rating                                                          4.7
#  Reviews                                                      174531
#  Size                                                            24M
#  Installs                                                10,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                                 Art & Design
#  Last Updated                                          July 31, 2018
#  Current Ver                                                   1.6.1
#  Android Ver                                              4.1 and up
#  Name: 45, dtype: object,
#  App               Install images with music to make video withou...
#  Category                                             ART_AND_DESIGN
#  Rating                                                          4.6
#  Reviews                                                        1070
#  Size                                                            26M
#  Installs                                                   100,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                                 Art & Design
#  Last Updated                                      November 14, 2017
#  Current Ver                                                     1.6
#  Android Ver                                              4.1 and up
#  Name: 46, dtype: object,
#  App               Little Teddy Bear Colouring Book Game
#  Category                                 ART_AND_DESIGN
#  Rating                                              4.2
#  Reviews                                              85
#  Size                                               8.0M
#  Installs                                       100,000+
#  Type                                               Free
#  Price                                                 0
#  Content Rating                                 Everyone
#  Genres                                     Art & Design
#  Last Updated                          December 17, 2017
#  Current Ver                                       2.0.0
#  Android Ver                                  4.1 and up
#  Name: 47, dtype: object,
#  App               How To Draw Food
#  Category            ART_AND_DESIGN
#  Rating                         4.3
#  Reviews                        845
#  Size                          7.9M
#  Installs                  100,000+
#  Type                          Free
#  Price                            0
#  Content Rating            Everyone
#  Genres                Art & Design
#  Last Updated          May 28, 2018
#  Current Ver                    1.0
#  Android Ver             2.3 and up
#  Name: 48, dtype: object,
#  App               Monster Truck Stunt 3D 2019
#  Category                    AUTO_AND_VEHICLES
#  Rating                                    4.2
#  Reviews                                   367
#  Size                                      25M
#  Installs                             100,000+
#  Type                                     Free
#  Price                                       0
#  Content Rating                       Everyone
#  Genres                        Auto & Vehicles
#  Last Updated                     May 10, 2018
#  Current Ver                               1.0
#  Android Ver                      4.0.3 and up
#  Name: 49, dtype: object,
#  App               Real Tractor Farming
#  Category             AUTO_AND_VEHICLES
#  Rating                             4.0
#  Reviews                           1598
#  Size                               56M
#  Installs                    1,000,000+
#  Type                              Free
#  Price                                0
#  Content Rating                Everyone
#  Genres                 Auto & Vehicles
#  Last Updated             July 26, 2018
#  Current Ver                       11.0
#  Android Ver                 4.1 and up
#  Name: 50, dtype: object,
#  App               Ultimate F1 Racing Championship
#  Category                        AUTO_AND_VEHICLES
#  Rating                                        3.8
#  Reviews                                       284
#  Size                                          57M
#  Installs                                 100,000+
#  Type                                         Free
#  Price                                           0
#  Content Rating                           Everyone
#  Genres                            Auto & Vehicles
#  Last Updated                        July 26, 2018
#  Current Ver                                   3.0
#  Android Ver                            4.1 and up
#  Name: 51, dtype: object,
#  App               Used Cars and Trucks for Sale
#  Category                      AUTO_AND_VEHICLES
#  Rating                                      4.6
#  Reviews                                   17057
#  Size                         Varies with device
#  Installs                             1,000,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                          Auto & Vehicles
#  Last Updated                      July 30, 2018
#  Current Ver                  Varies with device
#  Android Ver                  Varies with device
#  Name: 52, dtype: object,
#  App               American Muscle Car Race
#  Category                 AUTO_AND_VEHICLES
#  Rating                                 3.9
#  Reviews                                129
#  Size                                   35M
#  Installs                          100,000+
#  Type                                  Free
#  Price                                    0
#  Content Rating                    Everyone
#  Genres                     Auto & Vehicles
#  Last Updated                 July 26, 2018
#  Current Ver                            3.0
#  Android Ver                     4.1 and up
#  Name: 53, dtype: object,
#  App               Offroad Oil Tanker Driver Transport Truck 2019
#  Category                                       AUTO_AND_VEHICLES
#  Rating                                                       4.3
#  Reviews                                                      542
#  Size                                                         33M
#  Installs                                                100,000+
#  Type                                                        Free
#  Price                                                          0
#  Content Rating                                          Everyone
#  Genres                                           Auto & Vehicles
#  Last Updated                                       July 31, 2018
#  Current Ver                                                  4.0
#  Android Ver                                           4.1 and up
#  Name: 54, dtype: object,
#  App               Tickets SDA 2018 and Exam from the State Traff...
#  Category                                          AUTO_AND_VEHICLES
#  Rating                                                          4.9
#  Reviews                                                       10479
#  Size                                                            33M
#  Installs                                                   100,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                              Auto & Vehicles
#  Last Updated                                          July 18, 2018
#  Current Ver                                                   1.7.1
#  Android Ver                                              4.0 and up
#  Name: 55, dtype: object,
#  App               Gas Prices (Germany only)
#  Category                  AUTO_AND_VEHICLES
#  Rating                                  4.4
#  Reviews                                 805
#  Size                                   5.6M
#  Installs                            50,000+
#  Type                                   Free
#  Price                                     0
#  Content Rating                     Everyone
#  Genres                      Auto & Vehicles
#  Last Updated                  July 29, 2018
#  Current Ver                           2.5.1
#  Android Ver                      4.4 and up
#  Name: 56, dtype: object,
#  App               Extreme Rally Championship
#  Category                   AUTO_AND_VEHICLES
#  Rating                                   4.2
#  Reviews                                  129
#  Size                                     54M
#  Installs                            100,000+
#  Type                                    Free
#  Price                                      0
#  Content Rating                      Everyone
#  Genres                       Auto & Vehicles
#  Last Updated                   July 26, 2018
#  Current Ver                              3.0
#  Android Ver                       4.1 and up
#  Name: 57, dtype: object,
#  App               Restart Navigator
#  Category          AUTO_AND_VEHICLES
#  Rating                          4.0
#  Reviews                        1403
#  Size                           201k
#  Installs                   100,000+
#  Type                           Free
#  Price                             0
#  Content Rating             Everyone
#  Genres              Auto & Vehicles
#  Last Updated        August 26, 2014
#  Current Ver                   1.0.1
#  Android Ver              2.2 and up
#  Name: 58, dtype: object,
#  App               REG - Check the regnumber, find information ab...
#  Category                                          AUTO_AND_VEHICLES
#  Rating                                                          3.9
#  Reviews                                                        3971
#  Size                                                           3.6M
#  Installs                                                   100,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                              Auto & Vehicles
#  Last Updated                                          July 30, 2018
#  Current Ver                                                   2.493
#  Android Ver                                              4.4 and up
#  Name: 59, dtype: object,
#  App                    CityBus Lviv
#  Category          AUTO_AND_VEHICLES
#  Rating                          4.6
#  Reviews                         534
#  Size                           5.7M
#  Installs                    10,000+
#  Type                           Free
#  Price                             0
#  Content Rating             Everyone
#  Genres              Auto & Vehicles
#  Last Updated           July 8, 2018
#  Current Ver                   1.9.1
#  Android Ver            4.0.3 and up
#  Name: 60, dtype: object,
#  App               CDL Practice Test 2018 Edition
#  Category                       AUTO_AND_VEHICLES
#  Rating                                       4.9
#  Reviews                                     7774
#  Size                                         17M
#  Installs                                100,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                           Auto & Vehicles
#  Last Updated                        July 3, 2018
#  Current Ver                                  1.7
#  Android Ver                           4.2 and up
#  Name: 61, dtype: object,
#  App               ezETC (ETC balance inquiry, meter trial, real-...
#  Category                                          AUTO_AND_VEHICLES
#  Rating                                                          4.3
#  Reviews                                                       38846
#  Size                                                           8.6M
#  Installs                                                 1,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                              Auto & Vehicles
#  Last Updated                                          July 28, 2018
#  Current Ver                                           2.20 Build 02
#  Android Ver                                              4.1 and up
#  Name: 62, dtype: object,
#  App               Free VIN Report for Used Cars
#  Category                      AUTO_AND_VEHICLES
#  Rating                                      4.6
#  Reviews                                    2431
#  Size                                       2.4M
#  Installs                               100,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                          Auto & Vehicles
#  Last Updated                      June 12, 2018
#  Current Ver                                1.37
#  Android Ver                          4.0 and up
#  Name: 63, dtype: object,
#  App               DMV Permit Practice Test 2018 Edition
#  Category                              AUTO_AND_VEHICLES
#  Rating                                              4.9
#  Reviews                                            6090
#  Size                                                27M
#  Installs                                       100,000+
#  Type                                               Free
#  Price                                                 0
#  Content Rating                                 Everyone
#  Genres                                  Auto & Vehicles
#  Last Updated                               July 3, 2018
#  Current Ver                                         1.7
#  Android Ver                                  4.2 and up
#  Name: 64, dtype: object,
#  App               Check Vehicle Tax
#  Category          AUTO_AND_VEHICLES
#  Rating                          3.9
#  Reviews                         295
#  Size                           2.7M
#  Installs                    10,000+
#  Type                           Free
#  Price                             0
#  Content Rating             Everyone
#  Genres              Auto & Vehicles
#  Last Updated          July 30, 2018
#  Current Ver                   0.2.1
#  Android Ver              4.4 and up
#  Name: 65, dtype: object,
#  App                Used Cars Mexico
#  Category          AUTO_AND_VEHICLES
#  Rating                          4.0
#  Reviews                         190
#  Size                           2.5M
#  Installs                    50,000+
#  Type                           Free
#  Price                             0
#  Content Rating             Everyone
#  Genres              Auto & Vehicles
#  Last Updated       October 14, 2016
#  Current Ver                     1.0
#  Android Ver              2.3 and up
#  Name: 66, dtype: object,
#  App               Ulysse Speedometer
#  Category           AUTO_AND_VEHICLES
#  Rating                           4.3
#  Reviews                        40211
#  Size              Varies with device
#  Installs                  5,000,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres               Auto & Vehicles
#  Last Updated           July 30, 2018
#  Current Ver       Varies with device
#  Android Ver       Varies with device
#  Name: 67, dtype: object,
#  App                           REPUVE
#  Category           AUTO_AND_VEHICLES
#  Rating                           3.9
#  Reviews                          356
#  Size              Varies with device
#  Installs                    100,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres               Auto & Vehicles
#  Last Updated            May 25, 2018
#  Current Ver       Varies with device
#  Android Ver       Varies with device
#  Name: 68, dtype: object,
#  App               Used cars for sale - Trovit
#  Category                    AUTO_AND_VEHICLES
#  Rating                                    4.2
#  Reviews                                 52530
#  Size                                     7.0M
#  Installs                           5,000,000+
#  Type                                     Free
#  Price                                       0
#  Content Rating                       Everyone
#  Genres                        Auto & Vehicles
#  Last Updated                    July 16, 2018
#  Current Ver                            4.47.3
#  Android Ver                      4.0.3 and up
#  Name: 69, dtype: object,
#  App               Fines of the State Traffic Safety Inspectorate...
#  Category                                          AUTO_AND_VEHICLES
#  Rating                                                          4.8
#  Reviews                                                      116986
#  Size                                                            35M
#  Installs                                                 5,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                              Auto & Vehicles
#  Last Updated                                         August 2, 2018
#  Current Ver                                                   1.9.7
#  Android Ver                                            4.0.3 and up
#  Name: 70, dtype: object,
#  App               SK Enca Direct Malls - Used Cars Search
#  Category                                AUTO_AND_VEHICLES
#  Rating                                                3.6
#  Reviews                                              1379
#  Size                                                  16M
#  Installs                                         500,000+
#  Type                                                 Free
#  Price                                                   0
#  Content Rating                                   Everyone
#  Genres                                    Auto & Vehicles
#  Last Updated                               August 2, 2018
#  Current Ver                                        2.2.21
#  Android Ver                                    4.2 and up
#  Name: 71, dtype: object,
#  App               Android Auto - Maps, Media, Messaging & Voice
#  Category                                      AUTO_AND_VEHICLES
#  Rating                                                      4.2
#  Reviews                                                  271920
#  Size                                                        16M
#  Installs                                            10,000,000+
#  Type                                                       Free
#  Price                                                         0
#  Content Rating                                             Teen
#  Genres                                          Auto & Vehicles
#  Last Updated                                      July 11, 2018
#  Current Ver                                  Varies with device
#  Android Ver                                          5.0 and up
#  Name: 72, dtype: object,
#  App                           PDD-UA
#  Category           AUTO_AND_VEHICLES
#  Rating                           4.8
#  Reviews                          736
#  Size              Varies with device
#  Installs                    100,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres               Auto & Vehicles
#  Last Updated           July 29, 2018
#  Current Ver                      2.9
#  Android Ver             2.3.3 and up
#  Name: 73, dtype: object,
#  App               Tickets SDA 2019 + Exam RF
#  Category                   AUTO_AND_VEHICLES
#  Rating                                   4.8
#  Reviews                                 7021
#  Size                                     17M
#  Installs                            500,000+
#  Type                                    Free
#  Price                                      0
#  Content Rating                      Everyone
#  Genres                       Auto & Vehicles
#  Last Updated                   July 27, 2018
#  Current Ver                             1.79
#  Android Ver                       4.0 and up
#  Name: 74, dtype: object,
# ...
#  Android Ver                                      Varies with device
#  Name: 1304, dtype: object,
#  App               Workout Trainer: fitness coach
#  Category                      HEALTH_AND_FITNESS
#  Rating                                       4.2
#  Reviews                                   100406
#  Size                          Varies with device
#  Installs                             10,000,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                          Health & Fitness
#  Last Updated                       June 30, 2018
#  Current Ver                   Varies with device
#  Android Ver                   Varies with device
#  Name: 1305, dtype: object,
#  App               Fabulous: Motivate Me! Meditate, Relax, Sleep
#  Category                                     HEALTH_AND_FITNESS
#  Rating                                                      4.6
#  Reviews                                                  205299
#  Size                                                        31M
#  Installs                                             5,000,000+
#  Type                                                       Free
#  Price                                                         0
#  Content Rating                                         Everyone
#  Genres                                         Health & Fitness
#  Last Updated                                      July 16, 2018
#  Current Ver                                                3.48
#  Android Ver                                          4.1 and up
#  Name: 1306, dtype: object,
#  App               StrongLifts 5x5 Workout Gym Log & Personal Tra...
#  Category                                         HEALTH_AND_FITNESS
#  Rating                                                          4.9
#  Reviews                                                       66791
#  Size                                                            10M
#  Installs                                                 1,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                             Health & Fitness
#  Last Updated                                          July 30, 2018
#  Current Ver                                      Varies with device
#  Android Ver                                      Varies with device
#  Name: 1307, dtype: object,
#  App               Run with Map My Run
#  Category           HEALTH_AND_FITNESS
#  Rating                            4.5
#  Reviews                        183669
#  Size                              57M
#  Installs                   5,000,000+
#  Type                             Free
#  Price                               0
#  Content Rating               Everyone
#  Genres               Health & Fitness
#  Last Updated            July 27, 2018
#  Current Ver                    18.7.1
#  Android Ver                5.0 and up
#  Name: 1308, dtype: object,
#  App                 7 Minute Workout
#  Category          HEALTH_AND_FITNESS
#  Rating                           4.5
#  Reviews                       399009
#  Size              Varies with device
#  Installs                 10,000,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres              Health & Fitness
#  Last Updated            June 8, 2018
#  Current Ver       Varies with device
#  Android Ver       Varies with device
#  Name: 1309, dtype: object,
#  App               Workout Tracker & Gym Trainer - Fitness Log Book
#  Category                                        HEALTH_AND_FITNESS
#  Rating                                                         4.6
#  Reviews                                                       5420
#  Size                                                           21M
#  Installs                                                  500,000+
#  Type                                                          Free
#  Price                                                            0
#  Content Rating                                            Everyone
#  Genres                                            Health & Fitness
#  Last Updated                                          June 5, 2018
#  Current Ver                                                 2.48.3
#  Android Ver                                             4.1 and up
#  Name: 1310, dtype: object,
#  App               Freeletics: Personal Trainer & Fitness Workouts
#  Category                                       HEALTH_AND_FITNESS
#  Rating                                                        4.5
#  Reviews                                                    130104
#  Size                                                          25M
#  Installs                                              10,000,000+
#  Type                                                         Free
#  Price                                                           0
#  Content Rating                                           Everyone
#  Genres                                           Health & Fitness
#  Last Updated                                       August 3, 2018
#  Current Ver                                                   5.3
#  Android Ver                                            5.0 and up
#  Name: 1311, dtype: object,
#  App                     Fitbit Coach
#  Category          HEALTH_AND_FITNESS
#  Rating                           4.6
#  Reviews                        28951
#  Size                             60M
#  Installs                  1,000,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres              Health & Fitness
#  Last Updated           July 16, 2018
#  Current Ver                      4.4
#  Android Ver               4.4 and up
#  Name: 1313, dtype: object,
#  App               JEFIT Workout Tracker, Weight Lifting, Gym Log...
#  Category                                         HEALTH_AND_FITNESS
#  Rating                                                          4.5
#  Reviews                                                       60096
#  Size                                                            27M
#  Installs                                                 5,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                                 Teen
#  Genres                                             Health & Fitness
#  Last Updated                                          April 7, 2018
#  Current Ver                                                    10.0
#  Android Ver                                            4.0.3 and up
#  Name: 1314, dtype: object,
#  App               Map My Ride GPS Cycling Riding
#  Category                      HEALTH_AND_FITNESS
#  Rating                                       4.5
#  Reviews                                   106547
#  Size                                         54M
#  Installs                              1,000,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                          Health & Fitness
#  Last Updated                       July 27, 2018
#  Current Ver                               18.7.1
#  Android Ver                           5.0 and up
#  Name: 1315, dtype: object,
#  App               Daily Workouts - Exercise Fitness Routine Trainer
#  Category                                         HEALTH_AND_FITNESS
#  Rating                                                          4.4
#  Reviews                                                      134195
#  Size                                             Varies with device
#  Installs                                                10,000,000+
#  Type                                                           Free
#  Price                                                             0
#  Content Rating                                             Everyone
#  Genres                                             Health & Fitness
#  Last Updated                                          June 14, 2018
#  Current Ver                                      Varies with device
#  Android Ver                                      Varies with device
#  Name: 1316, dtype: object,
#  App               Google Fit - Fitness Tracking
#  Category                     HEALTH_AND_FITNESS
#  Rating                                      3.9
#  Reviews                                  249855
#  Size                         Varies with device
#  Installs                            10,000,000+
#  Type                                       Free
#  Price                                         0
#  Content Rating                         Everyone
#  Genres                         Health & Fitness
#  Last Updated                      July 24, 2018
#  Current Ver                  Varies with device
#  Android Ver                  Varies with device
#  Name: 1317, dtype: object,
#  App               Weight Loss Running by Verv
#  Category                   HEALTH_AND_FITNESS
#  Rating                                    4.5
#  Reviews                                 27396
#  Size                                      59M
#  Installs                           1,000,000+
#  Type                                     Free
#  Price                                       0
#  Content Rating                     Mature 17+
#  Genres                       Health & Fitness
#  Last Updated                    July 16, 2018
#  Current Ver                             6.5.3
#  Android Ver                        4.1 and up
#  Name: 1318, dtype: object,
#  App               Sworkit: Workouts & Fitness Plans
#  Category                         HEALTH_AND_FITNESS
#  Rating                                          4.6
#  Reviews                                      109756
#  Size                                            78M
#  Installs                                 5,000,000+
#  Type                                           Free
#  Price                                             0
#  Content Rating                             Everyone
#  Genres                             Health & Fitness
#  Last Updated                         August 1, 2018
#  Current Ver                                   8.2.0
#  Android Ver                            4.0.3 and up
#  Name: 1320, dtype: object,
#  App               Map My Fitness Workout Trainer
#  Category                      HEALTH_AND_FITNESS
#  Rating                                       4.4
#  Reviews                                    38343
#  Size                                         55M
#  Installs                              1,000,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                          Health & Fitness
#  Last Updated                       July 27, 2018
#  Current Ver                               18.7.1
#  Android Ver                           5.0 and up
#  Name: 1321, dtype: object,
#  App               Sports Tracker Running Cycling
#  Category                      HEALTH_AND_FITNESS
#  Rating                                       4.5
#  Reviews                                   190247
#  Size                          Varies with device
#  Installs                              5,000,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                          Health & Fitness
#  Last Updated                      August 3, 2018
#  Current Ver                   Varies with device
#  Android Ver                   Varies with device
#  Name: 1322, dtype: object,
#  App               Seven - 7 Minute Workout Training Challenge
#  Category                                   HEALTH_AND_FITNESS
#  Rating                                                    4.5
#  Reviews                                                 75571
#  Size                                       Varies with device
#  Installs                                           1,000,000+
#  Type                                                     Free
#  Price                                                       0
#  Content Rating                                       Everyone
#  Genres                                       Health & Fitness
#  Last Updated                                   August 3, 2018
#  Current Ver                                             7.2.5
#  Android Ver                                Varies with device
#  Name: 1325, dtype: object,
#  App               Daily Yoga - Yoga Fitness Plans
#  Category                       HEALTH_AND_FITNESS
#  Rating                                        4.4
#  Reviews                                     70769
#  Size                                          35M
#  Installs                               5,000,000+
#  Type                                         Free
#  Price                                           0
#  Content Rating                           Everyone
#  Genres                           Health & Fitness
#  Last Updated                        July 24, 2018
#  Current Ver                                6.2.73
#  Android Ver                            4.0 and up
#  Name: 1326, dtype: object,
#  App                      Pocket Yoga
#  Category          HEALTH_AND_FITNESS
#  Rating                           4.4
#  Reviews                         2107
#  Size              Varies with device
#  Installs                    100,000+
#  Type                            Paid
#  Price                          $2.99
#  Content Rating              Everyone
#  Genres              Health & Fitness
#  Last Updated       December 22, 2015
#  Current Ver       Varies with device
#  Android Ver       Varies with device
#  Name: 1327, dtype: object,
#  App               Relax Meditation: Sleep with Sleep Sounds
#  Category                                 HEALTH_AND_FITNESS
#  Rating                                                  4.4
#  Reviews                                               26540
#  Size                                                    43M
#  Installs                                         1,000,000+
#  Type                                                   Free
#  Price                                                     0
#  Content Rating                                     Everyone
#  Genres                                     Health & Fitness
#  Last Updated                               February 9, 2017
#  Current Ver                                           2.5.1
#  Android Ver                                    4.0.3 and up
#  Name: 1328, dtype: object,
#  App               Free Meditation - Take a Break
#  Category                      HEALTH_AND_FITNESS
#  Rating                                       4.2
#  Reviews                                     1608
#  Size                                         39M
#  Installs                                100,000+
#  Type                                        Free
#  Price                                          0
#  Content Rating                          Everyone
#  Genres                          Health & Fitness
#  Last Updated                       July 28, 2016
#  Current Ver                                  6.7
#  Android Ver                         2.3.3 and up
#  Name: 1329, dtype: object,
#  App                      Meditate OM
#  Category          HEALTH_AND_FITNESS
#  Rating                           4.5
#  Reviews                        19074
#  Size                            4.2M
#  Installs                  1,000,000+
#  Type                            Free
#  Price                              0
#  Content Rating              Everyone
#  Genres              Health & Fitness
#  Last Updated        January 17, 2018
#  Current Ver                     16.0
#  Android Ver               4.0 and up
#  Name: 1330, dtype: object,
#  ...]

# %%
android_clean = pd.DataFrame(android_clean)

# %%
# Function to check if 'App' is a non-English application

# %%
def is_english(app_name):
    lst = []
    for i in app_name:
        if ord(i) > 127:
            lst.append(False)
        else:
            lst.append(True)
            
    check = set(lst)
    
    if False in check:
        return False
    else:
        return True

# %%
is_english("Instagram")
# Out:
# True

# %%
is_english("Instagram🙂")
# Out:
# False

# %%
# to minimize the impact of data loss - we will only remove an app if its name has more than three non-Ascii characters

# %%
def is_english(app_name):
    lst = []
    for i in app_name:
        if ord(i) > 127:
            lst.append(False)
        else:
            lst.append(True)
            
    non_ascii = 0 
    for j in lst:
        if j == False:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

# %%
is_english("Instagram🙂")
# Out:
# True

# %%
android_english = android_clean[android_clean["App"].apply(is_english)]

# %%
android_english.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN    4.4
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
#
#                     Genres     Last Updated         Current Ver   Android Ver
# 0             Art & Design  January 7, 2018               1.0.0  4.0.3 and up
# 2             Art & Design   August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design     June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity    June 20, 2018                 1.1    4.4 and up
# 5             Art & Design   March 26, 2017                 1.0    2.3 and up

# %%
android_english.shape
# Out:
# (9615, 13)

# %%
android_english["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$11.99', '$79.99', '$16.99', '$14.99', '$1.00',
#        '$29.99', '$12.99', '$2.49', '$24.99', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
android_final = android_english[android_english["Price"] == "0"]

# %%
android_final.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN    4.4
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
#
#                     Genres     Last Updated         Current Ver   Android Ver
# 0             Art & Design  January 7, 2018               1.0.0  4.0.3 and up
# 2             Art & Design   August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design     June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity    June 20, 2018                 1.1    4.4 and up
# 5             Art & Design   March 26, 2017                 1.0    2.3 and up

# %%
android_final.shape
# Out:
# (8863, 13)

# %%
# DATA CLEANING COMPLETE

# %%
# ANALYSIS STARTED

# %%
## normalize True ll divide the propotion with total

# %%
android_final['Category'].value_counts(normalize = True)*100 #Multiply by 100 will give percentage
# Out:
# FAMILY                 18.932641
# GAME                    9.691978
# TOOLS                   8.450863
# BUSINESS                4.592125
# LIFESTYLE               3.915153
# PRODUCTIVITY            3.892587
# FINANCE                 3.700779
# MEDICAL                 3.520253
# SPORTS                  3.396141
# PERSONALIZATION         3.317161
# COMMUNICATION           3.238181
# HEALTH_AND_FITNESS      3.080221
# PHOTOGRAPHY             2.944827
# NEWS_AND_MAGAZINES      2.798150
# SOCIAL                  2.662755
# TRAVEL_AND_LOCAL        2.335552
# SHOPPING                2.245289
# BOOKS_AND_REFERENCE     2.143744
# DATING                  1.861672
# VIDEO_PLAYERS           1.793975
# MAPS_AND_NAVIGATION     1.399075
# FOOD_AND_DRINK          1.241115
# EDUCATION               1.173418
# ENTERTAINMENT           0.959043
# LIBRARIES_AND_DEMO      0.936477
# AUTO_AND_VEHICLES       0.925195
# HOUSE_AND_HOME          0.823649
# WEATHER                 0.801083
# EVENTS                  0.710820
# PARENTING               0.654406
# ART_AND_DESIGN          0.643123
# COMICS                  0.620557
# BEAUTY                  0.597992
# Name: Category, dtype: float64

# %%
#Data

categories = android_final["Category"].value_counts().index[:15]
counts = android_final["Category"].value_counts().values[:15]
percentage = round(android_final["Category"].value_counts(normalize = True)*100, 1)[:15]

#create barchart
plt.figure(figsize=(12,8))
bars = plt.bar(categories, counts, color='lightgray', alpha=0.75, edgecolor='black', linewidth=1.5)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(axis='x', linestyle='')
plt.xticks(fontsize=12) #customized tick labels
plt.yticks(range(0,3000, 500), [], fontsize=12) # customized tick labels and customized y ticks range
plt.tick_params(bottom = 0, left = 0)

# find a category with the highest count
max_count_category = categories[counts.argmax()]

#Highlight the bar for the category for the highest count
max_count_index = list(categories).index(max_count_category)
bars[max_count_index].set_color('salmon')
bars[max_count_index].set_edgecolor('black')

# Adding data labels and percentage inside each bar
for bar, perc in zip(bars, percentage):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 20, '%d' %int(height), ha='center', va='bottom', fontsize=10)
    plt.text(bar.get_x() + bar.get_width()/2, height/2, f'{perc}%' , ha='center', va='center', fontsize=10, color='black')
             
# Adding a background color
ax = plt.gca()
ax.set_facecolor('#f7f7f7')

#Adding chart title inside the chart
plt.text(0.5, 0.95, "Top Android App Categories", horizontalalignment='center', fontsize=16, transform=plt.gca().transAxes, color ='gray', fontweight='bold')

# Adding conclusion inside the chart
plt.text(0.5, 0.86, 'The "FAMILY" category stands out as the most prevalent among the top Android app categories, \n showcasing a value of 1678', horizontalalignment='center', fontsize=14, transform=plt.gca().transAxes, color='gray')
             
#Remove spines
for i in ["top", "right", "left"]:
    plt.gca().spines[i].set_visible(False)
             
plt.tight_layout() # adjust layout to prevent clipping

plt.show()

# %%
categories[counts.argmax()]
# Out:
# 'FAMILY'

# %%
counts.argmax()
# Out:
# 0

# %%
categories
# Out:
# Index(['FAMILY', 'GAME', 'TOOLS', 'BUSINESS', 'LIFESTYLE', 'PRODUCTIVITY',
#        'FINANCE', 'MEDICAL', 'SPORTS', 'PERSONALIZATION', 'COMMUNICATION',
#        'HEALTH_AND_FITNESS', 'PHOTOGRAPHY', 'NEWS_AND_MAGAZINES', 'SOCIAL'],
#       dtype='object')

# %%
android_final[android_final["Category"] =="FAMILY"]
# Out:
#                                                      App Category Rating  \
# 2017                        Jewels Crush- Match 3 Puzzle   FAMILY    4.4
# 2018                                    Coloring & Learn   FAMILY    4.4
# 2019                                             Mahjong   FAMILY    4.5
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY    4.6
# 2021                                       Toy Pop Cubes   FAMILY    4.5
# ...                                                  ...      ...    ...
# 10821                                            Poop FR   FAMILY    NaN
# 10827                                 Fr Agnel Ambarnath   FAMILY    4.2
# 10834                                      FR Calculator   FAMILY    4.0
# 10836                                   Sya9a Maroc - FR   FAMILY    4.5
# 10837                   Fr. Mike Schmitz Audio Teachings   FAMILY    5.0
#
#       Reviews  Size    Installs  Type Price Content Rating  \
# 2017    14774   19M  1,000,000+  Free     0       Everyone
# 2018    12753   51M  5,000,000+  Free     0       Everyone
# 2019    33983   22M  5,000,000+  Free     0       Everyone
# 2020    20267   46M  1,000,000+  Free     0       Everyone
# 2021     5761   21M  1,000,000+  Free     0       Everyone
# ...       ...   ...         ...   ...   ...            ...
# 10821       6  2.5M         50+  Free     0       Everyone
# 10827     117   13M      5,000+  Free     0       Everyone
# 10834       7  2.6M        500+  Free     0       Everyone
# 10836      38   53M      5,000+  Free     0       Everyone
# 10837       4  3.6M        100+  Free     0       Everyone
#
#                        Genres    Last Updated Current Ver   Android Ver
# 2017       Casual;Brain Games   July 23, 2018    1.9.3901  4.0.3 and up
# 2018   Educational;Creativity   July 17, 2018        1.49  4.0.3 and up
# 2019       Puzzle;Brain Games  August 2, 2018   1.24.3181  4.0.3 and up
# 2020    Educational;Education   July 16, 2018     1.1.6.7    4.1 and up
# 2021       Casual;Brain Games    July 4, 2018    1.8.3181  4.0.3 and up
# ...                       ...             ...         ...           ...
# 10821           Entertainment    May 29, 2018         1.0  4.0.3 and up
# 10827               Education   June 13, 2018      2.0.20  4.0.3 and up
# 10834               Education   June 18, 2017       1.0.0    4.1 and up
# 10836               Education   July 25, 2017        1.48    4.1 and up
# 10837               Education    July 6, 2018         1.0    4.1 and up
#
# [1678 rows x 13 columns]

# %%
# Most popular app by Genre on google play

# %%
android_final["Installs"].value_counts(normalize = True)*100
# Out:
# 1,000,000+        15.739592
# 100,000+          11.553650
# 10,000,000+       10.515627
# 10,000+           10.199707
# 1,000+             8.405732
# 100+               6.916394
# 5,000,000+         6.837414
# 500,000+           5.573733
# 50,000+            4.772650
# 5,000+             4.513145
# 10+                3.542818
# 500+               3.249464
# 50,000,000+        2.290421
# 100,000,000+       2.121178
# 50+                1.918086
# 5+                 0.789800
# 1+                 0.507729
# 500,000,000+       0.270789
# 1,000,000,000+     0.225657
# 0+                 0.045131
# 0                  0.011283
# Name: Installs, dtype: float64

# %%
android_final["Installs_int"] = android_final["Installs"].str.replace(",", "").str.replace("+", "").astype(int)
# Out:
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_10012\1127918135.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   android_final["Installs_int"] = android_final["Installs"].str.replace(",", "").str.replace("+", "").astype(int)
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_10012\1127918135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   android_final["Installs_int"] = android_final["Installs"].str.replace(",", "").str.replace("+", "").astype(int)

# %%
android_final["Installs_int"]
# Out:
# 0           10000
# 2         5000000
# 3        50000000
# 4          100000
# 5           50000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_int, Length: 8863, dtype: int32

# %%
install_frq = android_final["Installs_int"].value_counts().sort_index()
install_frq = install_frq[install_frq.index > 500]
install_frq
# Out:
# 1000           745
# 5000           400
# 10000          904
# 50000          423
# 100000        1024
# 500000         494
# 1000000       1395
# 5000000        606
# 10000000       932
# 50000000       203
# 100000000      188
# 500000000       24
# 1000000000      20
# Name: Installs_int, dtype: int64

# %%
install_frq_per = round(android_final["Installs_int"].value_counts(normalize=True)*100,2).sort_index()
install_frq_per = install_frq_per[install_frq_per.index > 500]
install_frq_per
# Out:
# 1000           8.41
# 5000           4.51
# 10000         10.20
# 50000          4.77
# 100000        11.55
# 500000         5.57
# 1000000       15.74
# 5000000        6.84
# 10000000      10.52
# 50000000       2.29
# 100000000      2.12
# 500000000      0.27
# 1000000000     0.23
# Name: Installs_int, dtype: float64

# %%
# alphanumeric units
def alphanumeric_units(value):
    if value >= 1e9:
        return f'{value / 1e9:.0f}B'
    if value >= 1e6:
        return f'{value / 1e6:.0f}M'
    if value >= 1e3:
        return f'{value / 1e3:.0f}K'
    else:
        return f'{value:0f}'

# %%
alphanumeric_units(10000000)
# Out:
# '10M'

# %%
install_frq.index = install_frq.index.map(alphanumeric_units)
install_frq
# Out:
# 1K       745
# 5K       400
# 10K      904
# 50K      423
# 100K    1024
# 500K     494
# 1M      1395
# 5M       606
# 10M      932
# 50M      203
# 100M     188
# 500M      24
# 1B        20
# Name: Installs_int, dtype: int64

# %%
#Data

categories = install_frq.index
counts = install_frq.values
percentage = install_frq_per.values

#create barchart
plt.figure(figsize=(12,8))
bars = plt.bar(categories, counts, color='skyblue', alpha=0.75, edgecolor='black', linewidth=1.5)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(axis='x', linestyle='')
plt.xticks(fontsize=12) #customized tick labels
plt.yticks(range(0,3000, 500), [], fontsize=12) # customized tick labels and customized y ticks range
plt.tick_params(bottom = 0, left = 0)

# find a category with the highest count
max_count_category = categories[counts.argmax()]

#Highlight the bar for the category for the highest count
max_count_index = list(categories).index(max_count_category)
bars[max_count_index].set_color('salmon')
bars[max_count_index].set_edgecolor('black')

# Adding data labels and percentage inside each bar
for bar, perc in zip(bars, percentage):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 20, '%d' %int(height), ha='center', va='bottom', fontsize=10)
    plt.text(bar.get_x() + bar.get_width()/2, height/2, f'{perc}%' , ha='center', va='center', fontsize=10, color='black')
             
# Adding a background color
ax = plt.gca()
ax.set_facecolor('#f7f7f7')

#Adding chart title inside the chart
plt.text(0.5, 0.95, "Distribution of Android App Installs", horizontalalignment='center', fontsize=16, transform=plt.gca().transAxes, color ='gray', fontweight='bold')

# Adding conclusion inside the chart
plt.text(0.5, -0.35, 'From the data provided 1M install range stands out with 1395 apps - Also Apps are inversely proportion to Installs',
             horizontalalignment='center', fontsize=11, transform=plt.gca().transAxes, color='gray')
             
#Remove spines
for i in ["top", "right", "left"]:
    plt.gca().spines[i].set_visible(False)
             
plt.tight_layout() # adjust layout to prevent clipping

plt.show()

# %%
categories_android = android_final["Category"].unique()
categories_android
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
pd.pivot_table(android_final, values = 'Installs_int', index='Category', aggfunc='mean')
# Out:
#                      Installs_int
# Category
# ART_AND_DESIGN       1.986335e+06
# AUTO_AND_VEHICLES    6.473178e+05
# BEAUTY               5.131519e+05
# BOOKS_AND_REFERENCE  8.767812e+06
# BUSINESS             1.712290e+06
# COMICS               8.176573e+05
# COMMUNICATION        3.845612e+07
# DATING               8.540288e+05
# EDUCATION            1.820673e+06
# ENTERTAINMENT        1.164071e+07
# EVENTS               2.535422e+05
# FAMILY               3.694276e+06
# FINANCE              1.387692e+06
# FOOD_AND_DRINK       1.924898e+06
# GAME                 1.556097e+07
# HEALTH_AND_FITNESS   4.188822e+06
# HOUSE_AND_HOME       1.331541e+06
# LIBRARIES_AND_DEMO   6.385037e+05
# LIFESTYLE            1.433676e+06
# MAPS_AND_NAVIGATION  4.056942e+06
# MEDICAL              1.206165e+05
# NEWS_AND_MAGAZINES   9.549178e+06
# PARENTING            5.426036e+05
# PERSONALIZATION      5.201483e+06
# PHOTOGRAPHY          1.780563e+07
# PRODUCTIVITY         1.678733e+07
# SHOPPING             7.036877e+06
# SOCIAL               2.325365e+07
# SPORTS               3.638640e+06
# TOOLS                1.068230e+07
# TRAVEL_AND_LOCAL     1.398408e+07
# VIDEO_PLAYERS        2.472787e+07
# WEATHER              5.074486e+06

# %%
# display without scientific notations
pd.options.display.float_format='{:0f}'.format

# %%
pd.pivot_table(android_final, values = 'Installs_int', index='Category', aggfunc='mean')
# Out:
#                        Installs_int
# Category
# ART_AND_DESIGN       1986335.087719
# AUTO_AND_VEHICLES     647317.817073
# BEAUTY                513151.886792
# BOOKS_AND_REFERENCE  8767811.894737
# BUSINESS             1712290.147420
# COMICS                817657.272727
# COMMUNICATION       38456119.167247
# DATING                854028.830303
# EDUCATION            1820673.076923
# ENTERTAINMENT       11640705.882353
# EVENTS                253542.222222
# FAMILY               3694276.334923
# FINANCE              1387692.475610
# FOOD_AND_DRINK       1924897.736364
# GAME                15560965.599534
# HEALTH_AND_FITNESS   4188821.985348
# HOUSE_AND_HOME       1331540.561644
# LIBRARIES_AND_DEMO    638503.734940
# LIFESTYLE            1433675.587896
# MAPS_AND_NAVIGATION  4056941.774194
# MEDICAL               120616.487179
# NEWS_AND_MAGAZINES   9549178.467742
# PARENTING             542603.620690
# PERSONALIZATION      5201482.612245
# PHOTOGRAPHY         17805627.643678
# PRODUCTIVITY        16787331.344928
# SHOPPING             7036877.311558
# SOCIAL              23253652.127119
# SPORTS               3638640.142857
# TOOLS               10682301.033378
# TRAVEL_AND_LOCAL    13984077.710145
# VIDEO_PLAYERS       24727872.452830
# WEATHER              5074486.197183

# %%
categories_installs = pd.pivot_table(android_final, values='Installs_int', index='Category', aggfunc='mean')
categories_installs = categories_installs.sort_values(by='Installs_int', ascending=False)
categories_installs = categories_installs['Installs_int']
categories_installs
# Out:
# Category
# COMMUNICATION         38456119.167247
# VIDEO_PLAYERS         24727872.452830
# SOCIAL                23253652.127119
# PHOTOGRAPHY           17805627.643678
# PRODUCTIVITY          16787331.344928
# GAME                  15560965.599534
# TRAVEL_AND_LOCAL      13984077.710145
# ENTERTAINMENT         11640705.882353
# TOOLS                 10682301.033378
# NEWS_AND_MAGAZINES     9549178.467742
# BOOKS_AND_REFERENCE    8767811.894737
# SHOPPING               7036877.311558
# PERSONALIZATION        5201482.612245
# WEATHER                5074486.197183
# HEALTH_AND_FITNESS     4188821.985348
# MAPS_AND_NAVIGATION    4056941.774194
# FAMILY                 3694276.334923
# SPORTS                 3638640.142857
# ART_AND_DESIGN         1986335.087719
# FOOD_AND_DRINK         1924897.736364
# EDUCATION              1820673.076923
# BUSINESS               1712290.147420
# LIFESTYLE              1433675.587896
# FINANCE                1387692.475610
# HOUSE_AND_HOME         1331540.561644
# DATING                  854028.830303
# COMICS                  817657.272727
# AUTO_AND_VEHICLES       647317.817073
# LIBRARIES_AND_DEMO      638503.734940
# PARENTING               542603.620690
# BEAUTY                  513151.886792
# EVENTS                  253542.222222
# MEDICAL                 120616.487179
# Name: Installs_int, dtype: float64

# %%
# alphanumeric units
def alphanumeric_units(value):
    if value >= 1e9:
        return f'{value / 1e9:.1f}B'
    if value >= 1e6:
        return f'{value / 1e6:.1f}M'
    if value >= 1e3:
        return f'{value / 1e3:.1f}K'
    else:
        return f'{value:1f}'

# %%
categories_installs_unit = categories_installs.map(alphanumeric_units)
categories_installs_unit
# Out:
# Category
# COMMUNICATION           38.5M
# VIDEO_PLAYERS           24.7M
# SOCIAL                  23.3M
# PHOTOGRAPHY             17.8M
# PRODUCTIVITY            16.8M
# GAME                    15.6M
# TRAVEL_AND_LOCAL        14.0M
# ENTERTAINMENT           11.6M
# TOOLS                   10.7M
# NEWS_AND_MAGAZINES       9.5M
# BOOKS_AND_REFERENCE      8.8M
# SHOPPING                 7.0M
# PERSONALIZATION          5.2M
# WEATHER                  5.1M
# HEALTH_AND_FITNESS       4.2M
# MAPS_AND_NAVIGATION      4.1M
# FAMILY                   3.7M
# SPORTS                   3.6M
# ART_AND_DESIGN           2.0M
# FOOD_AND_DRINK           1.9M
# EDUCATION                1.8M
# BUSINESS                 1.7M
# LIFESTYLE                1.4M
# FINANCE                  1.4M
# HOUSE_AND_HOME           1.3M
# DATING                 854.0K
# COMICS                 817.7K
# AUTO_AND_VEHICLES      647.3K
# LIBRARIES_AND_DEMO     638.5K
# PARENTING              542.6K
# BEAUTY                 513.2K
# EVENTS                 253.5K
# MEDICAL                120.6K
# Name: Installs_int, dtype: object

# %%
#Data

categories = categories_installs.index[:15]
counts = categories_installs.values[:15]
percentage = categories_installs_unit.values[:15]

#create barchart
plt.figure(figsize=(12,8))
bars = plt.bar(categories, counts, color='skyblue', alpha=0.75, edgecolor='black', linewidth=1.5)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(axis='x', linestyle='')
plt.xticks(fontsize=12) #customized tick labels
plt.yticks(range(0,60000000, 10000000), [], fontsize=12) # customized tick labels and customized y ticks range
plt.tick_params(bottom = 0, left = 0)

# find a category with the highest count
max_count_category = categories[counts.argmax()]

#Highlight the bar for the category for the highest count
max_count_index = list(categories).index(max_count_category)
bars[max_count_index].set_color('salmon')
bars[max_count_index].set_edgecolor('black')

# Adding data labels and percentage inside each bar
for bar, perc in zip(bars, percentage):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 20, '%d' %int(height), ha='center', va='bottom', fontsize=10)
    plt.text(bar.get_x() + bar.get_width()/2, height/2, f'{perc}%' , ha='center', va='center', fontsize=10, color='black')
             
# Adding a background color
ax = plt.gca()
ax.set_facecolor('#f7f7f7')

#Adding chart title inside the chart
plt.text(0.5, 0.95, "Average distribution of Android App Installs by category", horizontalalignment='center', fontsize=16, transform=plt.gca().transAxes, color ='gray', fontweight='bold')

# Adding conclusion inside the chart
plt.text(0.5, 0.35, 'Communication apps lead the pack with 38.5M installs \n followed closely by video player',
             horizontalalignment='center', fontsize=11, transform=plt.gca().transAxes, color='gray')
             
#Remove spines
for i in ["top", "right", "left"]:
    plt.gca().spines[i].set_visible(False)
             
plt.tight_layout() # adjust layout to prevent clipping

plt.show()

# %%
category_group=android_final.groupby('Category')

# %%
COMMUNICATION = category_group.get_group('COMMUNICATION').sort_values(by='Installs_int', ascending=False)
COMMUNICATION.head()
# Out:
#                                           App       Category   Rating  \
# 336                        WhatsApp Messenger  COMMUNICATION 4.400000
# 382  Messenger – Text and Video Chat for Free  COMMUNICATION 4.000000
# 464                                  Hangouts  COMMUNICATION 4.000000
# 411              Google Chrome: Fast & Secure  COMMUNICATION 4.300000
# 391             Skype - free IM & video calls  COMMUNICATION 4.100000
#
#       Reviews                Size        Installs  Type Price Content Rating  \
# 336  69119316  Varies with device  1,000,000,000+  Free     0       Everyone
# 382  56646578  Varies with device  1,000,000,000+  Free     0       Everyone
# 464   3419513  Varies with device  1,000,000,000+  Free     0       Everyone
# 411   9643041  Varies with device  1,000,000,000+  Free     0       Everyone
# 391  10484169  Varies with device  1,000,000,000+  Free     0       Everyone
#
#             Genres    Last Updated         Current Ver         Android Ver  \
# 336  Communication  August 3, 2018  Varies with device  Varies with device
# 382  Communication  August 1, 2018  Varies with device  Varies with device
# 464  Communication   July 21, 2018  Varies with device  Varies with device
# 411  Communication  August 1, 2018  Varies with device  Varies with device
# 391  Communication  August 3, 2018  Varies with device  Varies with device
#
#      Installs_int
# 336    1000000000
# 382    1000000000
# 464    1000000000
# 411    1000000000
# 391    1000000000

# %%
categories_installs.index[:15]
# Out:
# Index(['COMMUNICATION', 'VIDEO_PLAYERS', 'SOCIAL', 'PHOTOGRAPHY',
#        'PRODUCTIVITY', 'GAME', 'TRAVEL_AND_LOCAL', 'ENTERTAINMENT', 'TOOLS',
#        'NEWS_AND_MAGAZINES', 'BOOKS_AND_REFERENCE', 'SHOPPING',
#        'PERSONALIZATION', 'WEATHER', 'HEALTH_AND_FITNESS'],
#       dtype='object', name='Category')

# %%
# alphanumeric units
def alphanumeric_units(value):
    if value >= 1e9:
        return f'{value / 1e9:.0f}B'
    if value >= 1e6:
        return f'{value / 1e6:.0f}M'
    if value >= 1e3:
        return f'{value / 1e3:.0f}K'
    else:
        return f'{value:0f}'

# %%
df=COMMUNICATION[['App', 'Installs_int']].head(15)
df['Installs_int_unit'] = df['Installs_int'].map(alphanumeric_units)
df
# Out:
#                                                     App  Installs_int  \
# 336                                  WhatsApp Messenger    1000000000
# 382            Messenger – Text and Video Chat for Free    1000000000
# 464                                            Hangouts    1000000000
# 411                        Google Chrome: Fast & Secure    1000000000
# 391                       Skype - free IM & video calls    1000000000
# 451                                               Gmail    1000000000
# 403                         LINE: Free Calls & Messages     500000000
# 4676                                    Viber Messenger     500000000
# 420         UC Browser - Fast Download Private & Secure     500000000
# 371               Google Duo - High Quality Video Calls     500000000
# 383                       imo free video calls and chat     500000000
# 393                                                 Who     100000000
# 4633        UC Browser Mini -Tiny Fast Private & Secure     100000000
# 4602  Truecaller: Caller ID, SMS spam blocking & Dialer     100000000
# 4592                                           Telegram     100000000
#
#      Installs_int_unit
# 336                 1B
# 382                 1B
# 464                 1B
# 411                 1B
# 391                 1B
# 451                 1B
# 403               500M
# 4676              500M
# 420               500M
# 371               500M
# 383               500M
# 393               100M
# 4633              100M
# 4602              100M
# 4592              100M

# %%
df = category_group.get_group('VIDEO_PLAYERS').sort_values(by='Installs_int', ascending=False)
df=df[['App', 'Installs_int']].head(15)
df['Installs_int_unit'] = df['Installs_int'].map(alphanumeric_units)
df
# Out:
#                                                      App  Installs_int  \
# 3665                                             YouTube    1000000000
# 3687                             Google Play Movies & TV    1000000000
# 3711                                           MX Player     500000000
# 3675                                     VLC for Android     100000000
# 4688              VivaVideo - Video Editor & Photo Movie     100000000
# 4032                                            Dubsmash     100000000
# 10647                                  Motorola FM Radio     100000000
# 4696   VideoShow-Video Editor, Video Maker, Beauty Ca...     100000000
# 3672                                    Motorola Gallery     100000000
# 3691                               Samsung Video Library      50000000
# 4038   DU Recorder – Screen Recorder, Video Editor, Live      50000000
# 3693                LIKE – Magic Video Maker & Community      50000000
# 3686                                          Vigo Video      50000000
# 4049                       KineMaster – Pro Video Editor      50000000
# 5612                                           Ringdroid      50000000
#
#       Installs_int_unit
# 3665                 1B
# 3687                 1B
# 3711               500M
# 3675               100M
# 4688               100M
# 4032               100M
# 10647              100M
# 4696               100M
# 3672               100M
# 3691                50M
# 4038                50M
# 3693                50M
# 3686                50M
# 4049                50M
# 5612                50M

# %%
df = category_group.get_group('SOCIAL').sort_values(by='Installs_int', ascending=False)
df=df[['App', 'Installs_int']].head(15)
df['Installs_int_unit'] = df['Installs_int'].map(alphanumeric_units)
df
# Out:
#                                          App  Installs_int Installs_int_unit
# 2544                                Facebook    1000000000                1B
# 2554                                 Google+    1000000000                1B
# 2604                               Instagram    1000000000                1B
# 2610                                Snapchat     500000000              500M
# 2546                           Facebook Lite     500000000              500M
# 3945          Tik Tok - including musical.ly     100000000              100M
# 2592            Tango - Live Video Broadcast     100000000              100M
# 6373                                      VK     100000000              100M
# 2552                               Pinterest     100000000              100M
# 3951                 BIGO LIVE - Live Stream     100000000              100M
# 2621                                LinkedIn     100000000              100M
# 2548                                  Tumblr     100000000              100M
# 2588          Badoo - Free Chat & Dating App     100000000              100M
# 2636                 Zello PTT Walkie Talkie      50000000               50M
# 2595  ooVoo Video Calls, Messaging & Stories      50000000               50M

# %%
df = category_group.get_group('PHOTOGRAPHY').sort_values(by='Installs_int', ascending=False)
df=df[['App', 'Installs_int']].head(15)
df['Installs_int_unit'] = df['Installs_int'].map(alphanumeric_units)
df
# Out:
#                                                     App  Installs_int  \
# 2884                                      Google Photos    1000000000
# 4574     S Photo Editor - Collage Maker , Photo Collage     100000000
# 2949  Camera360: Selfie Photo Editor with Funny Sticker     100000000
# 2908                                            Retrica     100000000
# 8307                         LINE Camera - Photo editor     100000000
# 2921                                   Photo Editor Pro     100000000
# 2847  Sweet Selfie - selfie camera, beauty cam, phot...     100000000
# 2937     BeautyPlus - Easy Photo Editor & Selfie Camera     100000000
# 2938   PicsArt Photo Studio: Collage Maker & Pic Editor     100000000
# 5057                                          AR effect     100000000
# 2833             YouCam Makeup - Magic Selfie Makeovers     100000000
# 2942    Z Camera - Photo Editor, Beauty Selfie, Collage     100000000
# 2943  PhotoGrid: Video & Pic Collage Maker, Photo Ed...     100000000
# 2944  Candy Camera - selfie, beauty camera, photo ed...     100000000
# 2945               YouCam Perfect - Selfie Photo Editor     100000000
#
#      Installs_int_unit
# 2884                1B
# 4574              100M
# 2949              100M
# 2908              100M
# 8307              100M
# 2921              100M
# 2847              100M
# 2937              100M
# 2938              100M
# 5057              100M
# 2833              100M
# 2942              100M
# 2943              100M
# 2944              100M
# 2945              100M

# %%
df = category_group.get_group('PRODUCTIVITY').sort_values(by='Installs_int', ascending=False)
df=df[['App', 'Installs_int']].head(15)
df['Installs_int_unit'] = df['Installs_int'].map(alphanumeric_units)
df
# Out:
#                                  App  Installs_int Installs_int_unit
# 3523                    Google Drive    1000000000                1B
# 3450                  Microsoft Word     500000000              500M
# 3562                 Google Calendar     500000000              500M
# 3574                     Cloud Print     500000000              500M
# 3473                         Dropbox     500000000              500M
# 3524            Adobe Acrobat Reader     100000000              100M
# 3489                   Samsung Notes     100000000              100M
# 3477                     Google Docs     100000000              100M
# 3493               SwiftKey Keyboard     100000000              100M
# 7808  CamScanner - Phone PDF Creator     100000000              100M
# 3469   ES File Explorer File Manager     100000000              100M
# 3486            Microsoft PowerPoint     100000000              100M
# 3467                     Google Keep     100000000              100M
# 3465               Microsoft OneNote     100000000              100M
# 3526                   Google Sheets     100000000              100M

# %% [markdown]
# ## ANALYSIS of Photography category & potential for Photo generation App in 2024
#
# ### CONCLUSION
#  The analysis of the photography category reveals a notable trend in the popularity of photo editing  using AI and making Text to picture applications, with several apps garnering over 100 million installs. This indicates a strong demand for photo related functionalities among users.
#
#  Given the observation, there appears to be significant potential for the development of a photo generation AI application in 2024. Such an app will capture user interest in the created application.
#
# Considering the success of exisiting photography apps and evolving preferences of users, investing in the development of a photo generation app seems promising for tapping into this lucrative market segment in 2024.
